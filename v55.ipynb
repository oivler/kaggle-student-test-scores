# %% [markdown]
# # Predicting Student Test Scores
# ## Score: 8.69599

# %%
import time
import hashlib
import numpy as np
import pandas as pd

import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.preprocessing import TargetEncoder

# %%
train = pd.read_csv('playground-series-s6e1/train.csv')

test = pd.read_csv('playground-series-s6e1/test.csv')

test_ids = test['id'].to_numpy()

y = train['exam_score'].to_numpy(dtype=float)

X = train.drop(columns=['id', 'exam_score'])
X_test = test.drop(columns=['id'])

ord_maps = {
    'sleep_quality': {'poor': 0, 'average': 1, 'good': 2},
    'facility_rating': {'low': 0, 'medium': 1, 'high': 2},
    'exam_difficulty': {'easy': 0, 'moderate': 1, 'hard': 2}
}

for col, mp in ord_maps.items():
    if col in X.columns:
        X[f'{col}_ord'] = X[col].map(mp).astype('float32')
        X_test[f'{col}_ord'] = X_test[col].map(mp).astype('float32')

cat_cols = X.select_dtypes(include=['object']).columns.tolist()
for c in cat_cols:
    X[c] = X[c].astype('category')
    X_test[c] = X_test[c].astype('category')

eps = 1e-5
study = X['study_hours'].clip(lower=0)
attend = X['class_attendance'].clip(lower=0)
sleep = X['sleep_hours'].clip(lower=0)
study_te = X_test['study_hours'].clip(lower=0)
attend_te = X_test['class_attendance'].clip(lower=0)
sleep_te = X_test['sleep_hours'].clip(lower=0)

X['study_sq'] = X['study_hours'] ** 2
X_test['study_sq'] = X_test['study_hours'] ** 2
X['attendance_sq'] = X['class_attendance'] ** 2
X_test['attendance_sq'] = X_test['class_attendance'] ** 2
X['sleep_sq'] = X['sleep_hours'] ** 2
X_test['sleep_sq'] = X_test['sleep_hours'] ** 2
X['age_sq'] = X['age'] ** 2
X_test['age_sq'] = X_test['age'] ** 2

X['sqrt_study'] = np.sqrt(study)
X_test['sqrt_study'] = np.sqrt(study_te)
X['sqrt_attendance'] = np.sqrt(attend)
X_test['sqrt_attendance'] = np.sqrt(attend_te)

if 'study_hours' in X.columns and 'sleep_quality_ord' in X.columns:
    X['int_study_x_sleepq'] = X['study_hours'].astype(float) * X['sleep_quality_ord'].astype(float)
    X_test['int_study_x_sleepq'] = X_test['study_hours'].astype(float) * X_test['sleep_quality_ord'].astype(float)

if 'study_hours' in X.columns and 'class_attendance' in X.columns:
    X['int_study_x_att'] = X['study_hours'].astype(float) * X['class_attendance'].astype(float)
    X_test['int_study_x_att'] = X_test['study_hours'].astype(float) * X_test['class_attendance'].astype(float)

if 'study_hours' in X.columns and 'sleep_hours' in X.columns:
    X['int_study_x_sleep'] = X['study_hours'].astype(float) * X['sleep_hours'].astype(float)
    X_test['int_study_x_sleep'] = X_test['study_hours'].astype(float) * X_test['sleep_hours'].astype(float)
    X['int_att_x_sleep'] = X['class_attendance'].astype(float) * X['sleep_hours'].astype(float)
    X_test['int_att_x_sleep'] = X_test['class_attendance'].astype(float) * X_test['sleep_hours'].astype(float)

if 'age' in X.columns and 'study_hours' in X.columns:
    X['int_age_x_study'] = X['age'].astype(float) * X['study_hours'].astype(float)
    X_test['int_age_x_study'] = X_test['age'].astype(float) * X_test['study_hours'].astype(float)

if 'sleep_hours' in X.columns:
    X['sleep_opt_dist2_8'] = (X['sleep_hours'].astype(float) - 8.0) ** 2
    X_test['sleep_opt_dist2_8'] = (X_test['sleep_hours'].astype(float) - 8.0) ** 2
    X['sleep_gap_8'] = (X['sleep_hours'] - 8.0).abs()
    X_test['sleep_gap_8'] = (X_test['sleep_hours'] - 8.0).abs()

if 'class_attendance' in X.columns:
    X['attendance_gap_100'] = (X['class_attendance'] - 100.0).abs()
    X_test['attendance_gap_100'] = (X_test['class_attendance'] - 100.0).abs()

X['study_over_sleep'] = X['study_hours'] / (X['sleep_hours'] + eps)
X_test['study_over_sleep'] = X_test['study_hours'] / (X_test['sleep_hours'] + eps)
X['attendance_over_sleep'] = X['class_attendance'] / (X['sleep_hours'] + eps)
X_test['attendance_over_sleep'] = X_test['class_attendance'] / (X_test['sleep_hours'] + eps)
X['attendance_over_study'] = X['class_attendance'] / (X['study_hours'] + eps)
X_test['attendance_over_study'] = X_test['class_attendance'] / (X_test['study_hours'] + eps)

if 'study_hours' in X.columns and 'class_attendance' in X.columns and 'sleep_hours' in X.columns:
    X['efficiency'] = (X['study_hours'] * X['class_attendance']) / (X['sleep_hours'] + 1)
    X_test['efficiency'] = (X_test['study_hours'] * X_test['class_attendance']) / (X_test['sleep_hours'] + 1)

X['high_att_high_study'] = ((X['class_attendance'] >= 90) & (X['study_hours'] >= 6)).astype(int)
X_test['high_att_high_study'] = ((X_test['class_attendance'] >= 90) & (X_test['study_hours'] >= 6)).astype(int)
X['ideal_sleep_flag'] = ((X['sleep_hours'] >= 7) & (X['sleep_hours'] <= 9)).astype(int)
X_test['ideal_sleep_flag'] = ((X_test['sleep_hours'] >= 7) & (X_test['sleep_hours'] <= 9)).astype(int)
X['high_study_flag'] = (X['study_hours'] >= 7).astype(int)
X_test['high_study_flag'] = (X_test['study_hours'] >= 7).astype(int)

if 'facility_rating_ord' in X.columns and 'sleep_quality_ord' in X.columns:
    X['facility_x_sleepq'] = X['facility_rating_ord'] * X['sleep_quality_ord']
    X_test['facility_x_sleepq'] = X_test['facility_rating_ord'] * X_test['sleep_quality_ord']
if 'exam_difficulty_ord' in X.columns and 'facility_rating_ord' in X.columns:
    X['difficulty_x_facility'] = X['exam_difficulty_ord'] * X['facility_rating_ord']
    X_test['difficulty_x_facility'] = X_test['exam_difficulty_ord'] * X_test['facility_rating_ord']

for c in ['study_hours', 'sleep_hours']:
    if c in X.columns:
        X[f'log1p_{c}'] = np.log1p(X[c].astype(float))
        X_test[f'log1p_{c}'] = np.log1p(X_test[c].astype(float))

bin_src_cols = [c for c in ['study_hours', 'sleep_hours', 'class_attendance', 'age'] if c in X.columns]
for c in bin_src_cols:
    _, bins = pd.qcut(X[c], q=5, duplicates='drop', retbins=True)
    bins[0] = -np.inf
    bins[-1] = np.inf
    bc = f'bin5_{c}'
    X[bc] = pd.cut(X[c], bins=bins, include_lowest=True).cat.codes.astype('int16')
    X_test[bc] = pd.cut(X_test[c], bins=bins, include_lowest=True).cat.codes.astype('int16')

bin_src_cols2 = [c for c in ['study_hours', 'sleep_hours', 'class_attendance'] if c in X.columns]
for c in bin_src_cols2:
    _, bins = pd.qcut(X[c], q=20, duplicates='drop', retbins=True)
    bins[0] = -np.inf
    bins[-1] = np.inf
    bc = f'bin_{c}'
    X[bc] = pd.cut(X[c], bins=bins, include_lowest=True).cat.codes.astype('int16')
    X_test[bc] = pd.cut(X_test[c], bins=bins, include_lowest=True).cat.codes.astype('int16')

# %%
EARLY_STOP = 100

xgb_params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'learning_rate': 0.004,
    'n_estimators': 20000,
    'max_depth': 9,
    'subsample': 0.78,
    'colsample_bytree': 0.55,
    'colsample_bynode': 0.65,
    'reg_lambda': 6.0,
    'reg_alpha': 0.15,
    'min_child_weight': 6,
    'gamma': 1e-6,
    'tree_method': 'hist',
    'enable_categorical': True,
    'early_stopping_rounds': EARLY_STOP,
    'random_state': 42
}

seeds = [420, 666, 80085]
n_splits = 10
ridge_n_splits = 5

USE_RIDGE_META = True

TE_SMOOTH = 5.0

te_cols = [c for c in ['course', 'exam_difficulty', 'study_method', 'sleep_quality', 'facility_rating', 'internet_access', 'gender'] if c in X.columns]
te_cols += [c for c in X.columns if str(c).startswith('bin_')]
te_cols = list(dict.fromkeys(te_cols))

te_pairs = []
for a, b in [('course', 'exam_difficulty'), ('study_method', 'exam_difficulty'), ('course', 'study_method')]:
    if a in X.columns and b in X.columns:
        te_pairs.append((a, b))

for c in te_cols:
    vc = pd.concat([X[c], X_test[c]]).value_counts(dropna=False)
    X[f'ce_{c}'] = X[c].map(vc).astype(float).fillna(0.0)
    X_test[f'ce_{c}'] = X_test[c].map(vc).astype(float).fillna(0.0)

t0 = time.time()

if USE_RIDGE_META:
    print('RIDGE_META: Training Ridge regression for meta-feature...')
    kf_ridge = KFold(n_splits=ridge_n_splits, shuffle=True, random_state=42)
    
    oof_ridge = np.zeros(len(X), dtype=float)
    test_preds_ridge = np.zeros((len(X_test), ridge_n_splits), dtype=float)
    
    ridge_alphas = np.logspace(-2, 2, 15)
    
    for fold, (tr_idx, va_idx) in enumerate(kf_ridge.split(X, y), start=1):
        X_tr_r, X_va_r = X.iloc[tr_idx].copy(), X.iloc[va_idx].copy()
        y_tr_r, y_va_r = y[tr_idx], y[va_idx]
        X_test_r = X_test.copy()
        
        encoder = TargetEncoder(smooth='auto', target_type='continuous')
        X_tr_enc = X_tr_r.copy()
        X_va_enc = X_va_r.copy()
        X_test_enc = X_test_r.copy()
        
        for col in cat_cols:
            if col in X_tr_r.columns:
                X_tr_enc[col] = encoder.fit_transform(X_tr_r[[col]], y_tr_r).ravel()
                X_va_enc[col] = encoder.transform(X_va_r[[col]]).ravel()
                X_test_enc[col] = encoder.transform(X_test_r[[col]]).ravel()
        
        numeric_cols = [c for c in X_tr_enc.columns if X_tr_enc[c].dtype in ['float64', 'float32', 'int64', 'int32', 'int16']]
        X_tr_enc = X_tr_enc[numeric_cols].astype(float)
        X_va_enc = X_va_enc[numeric_cols].astype(float)
        X_test_enc = X_test_enc[numeric_cols].astype(float)
        
        ridge = RidgeCV(alphas=ridge_alphas, cv=3, scoring='neg_root_mean_squared_error')
        ridge.fit(X_tr_enc, y_tr_r)
        
        oof_ridge[va_idx] = np.clip(ridge.predict(X_va_enc), 0, 100)
        test_preds_ridge[:, fold - 1] = np.clip(ridge.predict(X_test_enc), 0, 100)
        
        fold_rmse = float(np.sqrt(mean_squared_error(y_va_r, oof_ridge[va_idx])))
        print(f'  Ridge Fold {fold}/{ridge_n_splits} RMSE: {fold_rmse:.5f}')
    
    ridge_oof_rmse = float(np.sqrt(mean_squared_error(y, oof_ridge)))
    print(f'RIDGE_META OOF RMSE: {ridge_oof_rmse:.5f}')
    
    X['ridge_meta'] = oof_ridge.astype('float32')
    X_test['ridge_meta'] = test_preds_ridge.mean(axis=1).astype('float32')
    print('RIDGE_META: Added ridge_meta feature to X and X_test')



y_bins_cat = pd.qcut(pd.Series(y), q=20, duplicates='drop')
y_bins = y_bins_cat.cat.codes.to_numpy()
min_count = int(pd.Series(y_bins).value_counts().min())
if n_splits > min_count:
    n_splits = max(2, min_count)
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

def te_fit_1_stats(X_ref, y_ref, col):
    y_s = pd.Series(y_ref, index=X_ref.index).astype(float)
    g = y_s.groupby(X_ref[col], observed=False).agg(['sum', 'count'])
    prior = float(y_s.mean())
    return g['sum'], g['count'], prior

def te_fit_2_stats(X_ref, y_ref, a, b):
    y_s = pd.Series(y_ref, index=X_ref.index).astype(float)
    key = X_ref[a].astype(str) + '|' + X_ref[b].astype(str)
    g = y_s.groupby(key).agg(['sum', 'count'])
    prior = float(y_s.mean())
    return g['sum'], g['count'], prior

def te_apply_fold_1(X_df, col, sum_s, cnt_s, prior, smooth):
    s = X_df[col].map(sum_s)
    c = X_df[col].map(cnt_s)
    s = s.astype(float)
    c = c.astype(float)
    enc = (s + prior * smooth) / (c + smooth)
    return enc.fillna(prior)

def te_apply_fold_2(X_df, a, b, sum_s, cnt_s, prior, smooth):
    key = X_df[a].astype(str) + '|' + X_df[b].astype(str)
    s = key.map(sum_s)
    c = key.map(cnt_s)
    s = s.astype(float)
    c = c.astype(float)
    enc = (s + prior * smooth) / (c + smooth)
    return enc.fillna(prior)

def add_te(X_tr, X_va, X_te, y_tr):
    add_tr = {}
    add_va = {}
    add_te2 = {}

    for c in te_cols:
        sum_s, cnt_s, prior = te_fit_1_stats(X_tr, y_tr, c)
        name = f'te_{c}'
        add_tr[name] = te_apply_fold_1(X_tr, c, sum_s, cnt_s, prior, TE_SMOOTH)
        add_va[name] = te_apply_fold_1(X_va, c, sum_s, cnt_s, prior, TE_SMOOTH)
        add_te2[name] = te_apply_fold_1(X_te, c, sum_s, cnt_s, prior, TE_SMOOTH)

    for a, b in te_pairs:
        sum_s, cnt_s, prior = te_fit_2_stats(X_tr, y_tr, a, b)
        name = f'te_{a}__{b}'
        add_tr[name] = te_apply_fold_2(X_tr, a, b, sum_s, cnt_s, prior, TE_SMOOTH)
        add_va[name] = te_apply_fold_2(X_va, a, b, sum_s, cnt_s, prior, TE_SMOOTH)
        add_te2[name] = te_apply_fold_2(X_te, a, b, sum_s, cnt_s, prior, TE_SMOOTH)

    X_tr2 = pd.concat([X_tr, pd.DataFrame(add_tr, index=X_tr.index)], axis=1)
    X_va2 = pd.concat([X_va, pd.DataFrame(add_va, index=X_va.index)], axis=1)
    X_te2 = pd.concat([X_te, pd.DataFrame(add_te2, index=X_te.index)], axis=1)

    return X_tr2, X_va2, X_te2


def cv_run_xgb(params, seeds, label):
    sum_oof = np.zeros(len(X), dtype=float)
    cnt_oof = np.zeros(len(X), dtype=float)
    sum_test = np.zeros(len(X_test), dtype=float)
    seeds_done = 0

    for s_i, seed in enumerate(seeds, start=1):
        oof = np.full(len(X), np.nan, dtype=float)
        test_pred_sum = np.zeros(len(X_test), dtype=float)
        rmse_scores = []
        folds_done = 0

        print(f'{label} SEED {seed} ({s_i}/{len(seeds)})')

        for fold, (tr_idx, va_idx) in enumerate(skf.split(X, y_bins), start=1):
            X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
            y_tr, y_va = y[tr_idx], y[va_idx]

            X_tr2, X_va2, X_test2 = add_te(X_tr, X_va, X_test, y_tr)

            p = {**params, 'random_state': seed}
            model = xgb.XGBRegressor(**p)

            model.fit(
                X_tr2,
                y_tr,
                eval_set=[(X_va2, y_va)],
                verbose=1000
            )

            va_p = np.clip(model.predict(X_va2), 0, 100)
            te_p = np.clip(model.predict(X_test2), 0, 100)

            oof[va_idx] = va_p
            test_pred_sum += te_p
            folds_done += 1

            fold_rmse = float(np.sqrt(mean_squared_error(y_va, va_p)))
            rmse_scores.append(fold_rmse)
            print(f'  Fold {fold}/{n_splits} RMSE: {fold_rmse:.5f}')

        if folds_done == 0:
            break

        test_pred = test_pred_sum / folds_done

        filled = ~np.isnan(oof)
        oof_filled = np.clip(oof[filled], 0, 100)
        sum_oof[filled] += oof_filled
        cnt_oof[filled] += 1.0

        sum_test += np.clip(test_pred, 0, 100)
        seeds_done += 1

        oof_rmse = float(np.sqrt(mean_squared_error(y[filled], oof_filled)))
        print(f'{label} Seed {seed} OOF RMSE: {oof_rmse:.5f} | Mean fold: {np.mean(rmse_scores):.5f} (+/- {np.std(rmse_scores):.5f})')

    denom = np.maximum(cnt_oof, 1.0)
    all_oof = np.clip(sum_oof / denom, 0, 100)

    if seeds_done > 0:
        all_test = np.clip(sum_test / seeds_done, 0, 100)
    else:
        all_test = np.zeros(len(X_test), dtype=float)

    filled_all = cnt_oof > 0
    if filled_all.any():
        final_oof_rmse = float(np.sqrt(mean_squared_error(y[filled_all], all_oof[filled_all])))
    else:
        final_oof_rmse = float('nan')

    print(f'{label} FINAL OOF RMSE: {final_oof_rmse:.5f}')

    return all_oof, all_test, final_oof_rmse


xgb_oof, xgb_test, _ = cv_run_xgb(xgb_params, seeds, 'XGB')
pred = np.clip(xgb_test, 0, 100)

# --- OOF residual group-bias correction (cheap “data edge”) ---
# This tries to remove systematic per-group under/over prediction using ONLY OOF residuals.
USE_RESIDUAL_CORR = True
RESID_SMOOTH = 200.0

if USE_RESIDUAL_CORR:
    base_oof = np.clip(xgb_oof, 0, 100)
    base_test = np.clip(pred, 0, 100)
    resid = (y - base_oof).astype(float)

    def apply_resid_corr(key_tr, key_te, resid_tr, smooth):
        s = pd.Series(resid_tr).groupby(key_tr, observed=False).sum()
        c = pd.Series(resid_tr).groupby(key_tr, observed=False).count()
        corr_tr = key_tr.map(s) / (key_tr.map(c) + smooth)
        corr_te = key_te.map(s) / (key_te.map(c) + smooth)
        return corr_tr.fillna(0.0).to_numpy(dtype=float), corr_te.fillna(0.0).to_numpy(dtype=float)

    corr_oof = np.zeros(len(X), dtype=float)
    corr_test = np.zeros(len(X_test), dtype=float)

    # single-group corrections
    for g in [c for c in ['course', 'study_method', 'exam_difficulty', 'sleep_quality', 'facility_rating', 'internet_access', 'gender'] if c in X.columns]:
        tr_key = X[g].astype(str)
        te_key = X_test[g].astype(str)
        co, ct = apply_resid_corr(tr_key, te_key, resid, RESID_SMOOTH)
        corr_oof += co
        corr_test += ct

    # high-signal pair corrections
    for a, b in [("course", "exam_difficulty"), ("course", "study_method"), ("study_method", "exam_difficulty")]:
        if a in X.columns and b in X.columns:
            tr_key = (X[a].astype(str) + '|' + X[b].astype(str))
            te_key = (X_test[a].astype(str) + '|' + X_test[b].astype(str))
            co, ct = apply_resid_corr(tr_key, te_key, resid, RESID_SMOOTH)
            corr_oof += co
            corr_test += ct

    # apply correction
    adj_oof = np.clip(base_oof + corr_oof, 0, 100)
    adj_rmse = float(np.sqrt(mean_squared_error(y, adj_oof)))
    print('RESIDUAL_CORR rmse', adj_rmse, 'corr_oof_std', float(np.std(corr_oof)), 'corr_test_std', float(np.std(corr_test)))

    pred = np.clip(base_test + corr_test, 0, 100)

submission = pd.DataFrame({'id': test_ids, 'exam_score': pred})

out_path = 'submission.csv'
submission.to_csv(out_path, index=False)
with open(out_path, 'rb') as f:
    md5 = hashlib.md5(f.read()).hexdigest()

print(out_path)
print('md5', md5)
print('pred_mean', float(np.mean(pred)), 'pred_std', float(np.std(pred)), 'pred_min', float(np.min(pred)), 'pred_max', float(np.max(pred)))
print('pred_ge_99_5', int(np.sum(pred >= 99.5)), 'pred_ge_97', int(np.sum(pred >= 97.0)))
# Out:
# RIDGE_META: Training Ridge regression for meta-feature...
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.29199e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28597e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.29067e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21476e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.2136e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21451e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34524e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34299e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34475e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.5276e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.52327e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.52665e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.74035e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.73198e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.73852e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.6872e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68559e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68685e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.25681e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.25369e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.25613e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28667e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28065e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28536e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.19003e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   Ridge Fold 1/5 RMSE: 8.87532
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28767e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.26481e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.26903e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21393e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.20952e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21033e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34363e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.33511e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.33668e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.52449e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.50804e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.51107e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.73434e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.70259e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.70845e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68604e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.67991e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68104e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.25457e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.24274e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.24492e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28235e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.25951e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.26373e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.17953e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   Ridge Fold 2/5 RMSE: 8.88054
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.26084e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.27877e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28011e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.20875e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21221e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21247e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.33363e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34031e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34081e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.50518e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.51809e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.51905e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.69707e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.72198e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.72384e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.67885e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68366e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68401e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.24068e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.24996e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.25065e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.25554e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.27347e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.27479e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.17913e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   Ridge Fold 3/5 RMSE: 8.87199
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.3164e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28992e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.30135e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21948e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21436e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21657e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.35434e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34447e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34873e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.54517e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.52611e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.53434e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.77426e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.73748e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.75335e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.69375e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68665e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68971e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.26944e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.25574e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.26165e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.31106e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28461e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.29603e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.19866e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   Ridge Fold 4/5 RMSE: 8.88266
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.29168e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.25073e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.27447e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.2147e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.2068e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.21138e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.34512e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.32986e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=2.33871e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.52737e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.49791e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.51499e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.73991e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.68303e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=8.71601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.68712e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.67614e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.6825e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.25664e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.23545e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.24774e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.28635e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.24544e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.26916e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\ol1v3_7dwns5u\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.17848e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
#   Ridge Fold 5/5 RMSE: 8.90111
# RIDGE_META OOF RMSE: 8.88233
# RIDGE_META: Added ridge_meta feature to X and X_test
# XGB SEED 420 (1/3)
# [0]	validation_0-rmse:18.85766
# [1000]	validation_0-rmse:8.78890
# [2000]	validation_0-rmse:8.75408
# [3000]	validation_0-rmse:8.74239
# [4000]	validation_0-rmse:8.73608
# [5000]	validation_0-rmse:8.73275
# [6000]	validation_0-rmse:8.73093
# [7000]	validation_0-rmse:8.72974
# [7268]	validation_0-rmse:8.72936
#   Fold 1/10 RMSE: 8.72931
# [0]	validation_0-rmse:18.86435
# [1000]	validation_0-rmse:8.80428
# [2000]	validation_0-rmse:8.76774
# [3000]	validation_0-rmse:8.75564
# [4000]	validation_0-rmse:8.74969
# [5000]	validation_0-rmse:8.74623
# [6000]	validation_0-rmse:8.74429
# [6817]	validation_0-rmse:8.74359
#   Fold 2/10 RMSE: 8.74352
# [0]	validation_0-rmse:18.85688
# [1000]	validation_0-rmse:8.78986
# [2000]	validation_0-rmse:8.75311
# [3000]	validation_0-rmse:8.74054
# [4000]	validation_0-rmse:8.73371
# [5000]	validation_0-rmse:8.72996
# [6000]	validation_0-rmse:8.72761
# [6818]	validation_0-rmse:8.72682
#   Fold 3/10 RMSE: 8.72678
# [0]	validation_0-rmse:18.86914
# [1000]	validation_0-rmse:8.75824
# [2000]	validation_0-rmse:8.72090
# [3000]	validation_0-rmse:8.70892
# [4000]	validation_0-rmse:8.70204
# [5000]	validation_0-rmse:8.69880
# [6000]	validation_0-rmse:8.69717
# [6710]	validation_0-rmse:8.69627
#   Fold 4/10 RMSE: 8.69623
# [0]	validation_0-rmse:18.83109
# [1000]	validation_0-rmse:8.83609
# [2000]	validation_0-rmse:8.80148
# [3000]	validation_0-rmse:8.78954
# [4000]	validation_0-rmse:8.78235
# [5000]	validation_0-rmse:8.77860
# [6000]	validation_0-rmse:8.77695
# [6572]	validation_0-rmse:8.77649
#   Fold 5/10 RMSE: 8.77641
# [0]	validation_0-rmse:18.86166
# [1000]	validation_0-rmse:8.79883
# [2000]	validation_0-rmse:8.76127
# [3000]	validation_0-rmse:8.74877
# [4000]	validation_0-rmse:8.74113
# [5000]	validation_0-rmse:8.73692
# [6000]	validation_0-rmse:8.73441
# [7000]	validation_0-rmse:8.73304
# [7239]	validation_0-rmse:8.73297
#   Fold 6/10 RMSE: 8.73290
# [0]	validation_0-rmse:18.86059
# [1000]	validation_0-rmse:8.80204
# [2000]	validation_0-rmse:8.76435
# [3000]	validation_0-rmse:8.75238
# [4000]	validation_0-rmse:8.74529
# [5000]	validation_0-rmse:8.74153
# [6000]	validation_0-rmse:8.73914
# [6451]	validation_0-rmse:8.73847
#   Fold 7/10 RMSE: 8.73845
# [0]	validation_0-rmse:18.85627
# [1000]	validation_0-rmse:8.79413
# [2000]	validation_0-rmse:8.75766
# [3000]	validation_0-rmse:8.74420
# [4000]	validation_0-rmse:8.73633
# [5000]	validation_0-rmse:8.73149
# [6000]	validation_0-rmse:8.72881
# [7000]	validation_0-rmse:8.72727
# [7232]	validation_0-rmse:8.72701
#   Fold 8/10 RMSE: 8.72693
# [0]	validation_0-rmse:18.86089
# [1000]	validation_0-rmse:8.77481
# [2000]	validation_0-rmse:8.73630
# [3000]	validation_0-rmse:8.72337
# [4000]	validation_0-rmse:8.71579
# [5000]	validation_0-rmse:8.71152
# [6000]	validation_0-rmse:8.70866
# [6191]	validation_0-rmse:8.70841
#   Fold 9/10 RMSE: 8.70834
# [0]	validation_0-rmse:18.86220
# [1000]	validation_0-rmse:8.79649
# [2000]	validation_0-rmse:8.75914
# [3000]	validation_0-rmse:8.74801
# [4000]	validation_0-rmse:8.74231
# [5000]	validation_0-rmse:8.73844
# [6000]	validation_0-rmse:8.73666
# [6212]	validation_0-rmse:8.73650
#   Fold 10/10 RMSE: 8.73645
# XGB Seed 420 OOF RMSE: 8.73156 | Mean fold: 8.73153 (+/- 0.02016)
# XGB SEED 666 (2/3)
# [0]	validation_0-rmse:18.85957
# [1000]	validation_0-rmse:8.78843
# [2000]	validation_0-rmse:8.75277
# [3000]	validation_0-rmse:8.74139
# [4000]	validation_0-rmse:8.73556
# [5000]	validation_0-rmse:8.73207
# [5712]	validation_0-rmse:8.73066
#   Fold 1/10 RMSE: 8.73057
# [0]	validation_0-rmse:18.86623
# [1000]	validation_0-rmse:8.80468
# [2000]	validation_0-rmse:8.76725
# [3000]	validation_0-rmse:8.75594
# [4000]	validation_0-rmse:8.74987
# [5000]	validation_0-rmse:8.74593
# [6000]	validation_0-rmse:8.74356
# [6626]	validation_0-rmse:8.74286
#   Fold 2/10 RMSE: 8.74285
# [0]	validation_0-rmse:18.85872
# [1000]	validation_0-rmse:8.79025
# [2000]	validation_0-rmse:8.75324
# [3000]	validation_0-rmse:8.74098
# [4000]	validation_0-rmse:8.73414
# [5000]	validation_0-rmse:8.73024
# [6000]	validation_0-rmse:8.72802
# [7000]	validation_0-rmse:8.72667
# [7160]	validation_0-rmse:8.72659
#   Fold 3/10 RMSE: 8.72654
# [0]	validation_0-rmse:18.87095
# [1000]	validation_0-rmse:8.75824
# [2000]	validation_0-rmse:8.72059
# [3000]	validation_0-rmse:8.70874
# [4000]	validation_0-rmse:8.70238
# [5000]	validation_0-rmse:8.69837
# [5293]	validation_0-rmse:8.69784
#   Fold 4/10 RMSE: 8.69781
# [0]	validation_0-rmse:18.83290
# [1000]	validation_0-rmse:8.83598
# [2000]	validation_0-rmse:8.80179
# [3000]	validation_0-rmse:8.79018
# [4000]	validation_0-rmse:8.78385
# [5000]	validation_0-rmse:8.77997
# [6000]	validation_0-rmse:8.77785
# [6371]	validation_0-rmse:8.77753
#   Fold 5/10 RMSE: 8.77745
# [0]	validation_0-rmse:18.86344
# [1000]	validation_0-rmse:8.79861
# [2000]	validation_0-rmse:8.76115
# [3000]	validation_0-rmse:8.74847
# [4000]	validation_0-rmse:8.74139
# [5000]	validation_0-rmse:8.73721
# [6000]	validation_0-rmse:8.73470
# [7000]	validation_0-rmse:8.73358
# [7059]	validation_0-rmse:8.73355
#   Fold 6/10 RMSE: 8.73348
# [0]	validation_0-rmse:18.86243
# [1000]	validation_0-rmse:8.80134
# [2000]	validation_0-rmse:8.76500
# [3000]	validation_0-rmse:8.75245
# [4000]	validation_0-rmse:8.74531
# [5000]	validation_0-rmse:8.74138
# [6000]	validation_0-rmse:8.73913
# [6413]	validation_0-rmse:8.73849
#   Fold 7/10 RMSE: 8.73847
# [0]	validation_0-rmse:18.85798
# [1000]	validation_0-rmse:8.79366
# [2000]	validation_0-rmse:8.75649
# [3000]	validation_0-rmse:8.74334
# [4000]	validation_0-rmse:8.73591
# [5000]	validation_0-rmse:8.73124
# [6000]	validation_0-rmse:8.72879
# [7000]	validation_0-rmse:8.72731
# [7904]	validation_0-rmse:8.72660
#   Fold 8/10 RMSE: 8.72654
# [0]	validation_0-rmse:18.86274
# [1000]	validation_0-rmse:8.77499
# [2000]	validation_0-rmse:8.73697
# [3000]	validation_0-rmse:8.72380
# [4000]	validation_0-rmse:8.71644
# [5000]	validation_0-rmse:8.71222
# [6000]	validation_0-rmse:8.70973
# [6552]	validation_0-rmse:8.70889
#   Fold 9/10 RMSE: 8.70887
# [0]	validation_0-rmse:18.86393
# [1000]	validation_0-rmse:8.79503
# [2000]	validation_0-rmse:8.75741
# [3000]	validation_0-rmse:8.74671
# [4000]	validation_0-rmse:8.74054
# [5000]	validation_0-rmse:8.73731
# [5868]	validation_0-rmse:8.73583
#   Fold 10/10 RMSE: 8.73577
# XGB Seed 666 OOF RMSE: 8.73186 | Mean fold: 8.73184 (+/- 0.02002)
# XGB SEED 80085 (3/3)
# [0]	validation_0-rmse:18.85789
# [1000]	validation_0-rmse:8.78894
# [2000]	validation_0-rmse:8.75293
# [3000]	validation_0-rmse:8.74162
# [4000]	validation_0-rmse:8.73473
# [5000]	validation_0-rmse:8.73074
# [6000]	validation_0-rmse:8.72881
# [6176]	validation_0-rmse:8.72873
#   Fold 1/10 RMSE: 8.72867
# [0]	validation_0-rmse:18.86452
# [1000]	validation_0-rmse:8.80393
# [2000]	validation_0-rmse:8.76622
# [3000]	validation_0-rmse:8.75512
# [4000]	validation_0-rmse:8.74890
# [5000]	validation_0-rmse:8.74534
# [6000]	validation_0-rmse:8.74320
# [6728]	validation_0-rmse:8.74245
#   Fold 2/10 RMSE: 8.74233
# [0]	validation_0-rmse:18.85699
# [1000]	validation_0-rmse:8.79059
# [2000]	validation_0-rmse:8.75302
# [3000]	validation_0-rmse:8.74003
# [4000]	validation_0-rmse:8.73321
# [5000]	validation_0-rmse:8.72906
# [6000]	validation_0-rmse:8.72720
# [6704]	validation_0-rmse:8.72670
#   Fold 3/10 RMSE: 8.72661
# [0]	validation_0-rmse:18.86925
# [1000]	validation_0-rmse:8.75935
# [2000]	validation_0-rmse:8.71997
# [3000]	validation_0-rmse:8.70758
# [4000]	validation_0-rmse:8.70164
# [5000]	validation_0-rmse:8.69833
# [6000]	validation_0-rmse:8.69636
# [6464]	validation_0-rmse:8.69601
#   Fold 4/10 RMSE: 8.69595
# [0]	validation_0-rmse:18.83124
# [1000]	validation_0-rmse:8.83607
# [2000]	validation_0-rmse:8.80201
# [3000]	validation_0-rmse:8.79060
# [4000]	validation_0-rmse:8.78416
# [5000]	validation_0-rmse:8.78020
# [6000]	validation_0-rmse:8.77802
# [6096]	validation_0-rmse:8.77807
#   Fold 5/10 RMSE: 8.77800
# [0]	validation_0-rmse:18.86182
# [1000]	validation_0-rmse:8.79808
# [2000]	validation_0-rmse:8.76085
# [3000]	validation_0-rmse:8.74780
# [4000]	validation_0-rmse:8.74071
# [5000]	validation_0-rmse:8.73588
# [6000]	validation_0-rmse:8.73345
# [6590]	validation_0-rmse:8.73261
#   Fold 6/10 RMSE: 8.73253
# [0]	validation_0-rmse:18.86079
# [1000]	validation_0-rmse:8.80158
# [2000]	validation_0-rmse:8.76428
# [3000]	validation_0-rmse:8.75160
# [4000]	validation_0-rmse:8.74442
# [5000]	validation_0-rmse:8.74060
# [5873]	validation_0-rmse:8.73863
#   Fold 7/10 RMSE: 8.73863
# [0]	validation_0-rmse:18.85639
# [1000]	validation_0-rmse:8.79309
# [2000]	validation_0-rmse:8.75630
# [3000]	validation_0-rmse:8.74304
# [4000]	validation_0-rmse:8.73576
# [5000]	validation_0-rmse:8.73144
# [6000]	validation_0-rmse:8.72925
# [7000]	validation_0-rmse:8.72735
# [7284]	validation_0-rmse:8.72715
#   Fold 8/10 RMSE: 8.72710
# [0]	validation_0-rmse:18.86113
# [1000]	validation_0-rmse:8.77504
# [2000]	validation_0-rmse:8.73685
# [3000]	validation_0-rmse:8.72371
# [4000]	validation_0-rmse:8.71689
# [5000]	validation_0-rmse:8.71283
# [6000]	validation_0-rmse:8.71037
# [7000]	validation_0-rmse:8.70925
# [7470]	validation_0-rmse:8.70908
#   Fold 9/10 RMSE: 8.70904
# [0]	validation_0-rmse:18.86237
# [1000]	validation_0-rmse:8.79596
# [2000]	validation_0-rmse:8.75882
# [3000]	validation_0-rmse:8.74757
# [4000]	validation_0-rmse:8.74140
# [5000]	validation_0-rmse:8.73818
# [6000]	validation_0-rmse:8.73632
# [6299]	validation_0-rmse:8.73604
#   Fold 10/10 RMSE: 8.73595
# XGB Seed 80085 OOF RMSE: 8.73151 | Mean fold: 8.73148 (+/- 0.02042)
# XGB FINAL OOF RMSE: 8.73063
# RESIDUAL_CORR rmse 8.730589071885088 corr_oof_std 0.03192710548182403 corr_test_std 0.03197998805833333
# submission.csv
# md5 eb4bf4aa706bfc0a4193cb980c20625b
# pred_mean 62.5227020375858 pred_std 16.76703429495937 pred_min 16.920795066384542 pred_max 100.0
# pred_ge_99_5 63 pred_ge_97 1378
